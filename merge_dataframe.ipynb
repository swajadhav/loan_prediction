# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 1. insert

# %%
df = pd.DataFrame({'a':[10,20,30],'b':[5,6,7],'c':[3,4,5]})
df
# Out:
#     a  b  c
# 0  10  5  3
# 1  20  6  4
# 2  30  7  5

# %%
df.insert(1,'D','Python')  # Column will be added at 1st index
df
# Out:
#     a       D  b  c
# 0  10  Python  5  3
# 1  20  Python  6  4
# 2  30  Python  7  5

# %%
df.insert(1,'D','Python',allow_duplicates=True)  # Column will be added at 1st index
df
# Out:
#     a       D       D       D  b  c
# 0  10  Python  Python  Python  5  3
# 1  20  Python  Python  Python  6  4
# 2  30  Python  Python  Python  7  5

# %%
df.insert(1,'E','data Science',allow_duplicates=True)  # Column will be added at 1st index
df
# Out:
#     a             E       D       D       D  b  c
# 0  10  data Science  Python  Python  Python  5  3
# 1  20  data Science  Python  Python  Python  6  4
# 2  30  data Science  Python  Python  Python  7  5

# %%
df.insert(1,'R','Machine Learning',allow_duplicates=True)  # Column will be added at 1st index
df
# Out:
#     a                 R             E       D       D       D  b  c
# 0  10  Machine Learning  data Science  Python  Python  Python  5  3
# 1  20  Machine Learning  data Science  Python  Python  Python  6  4
# 2  30  Machine Learning  data Science  Python  Python  Python  7  5

# %%
df.insert(4,'R','Machine Learning',allow_duplicates=True)  # Column will be added at 1st index
df
# Out:
#     a                 R             E       D                 R       D  \
# 0  10  Machine Learning  data Science  Python  Machine Learning  Python
# 1  20  Machine Learning  data Science  Python  Machine Learning  Python
# 2  30  Machine Learning  data Science  Python  Machine Learning  Python
#
#         D  b  c
# 0  Python  5  3
# 1  Python  6  4
# 2  Python  7  5

# %%
df.insert(4,'R',100,allow_duplicates=True)  # Column will be added at 1st index
df
# Out:
#     a                 R             E       D    R                 R       D  \
# 0  10  Machine Learning  data Science  Python  100  Machine Learning  Python
# 1  20  Machine Learning  data Science  Python  100  Machine Learning  Python
# 2  30  Machine Learning  data Science  Python  100  Machine Learning  Python
#
#         D  b  c
# 0  Python  5  3
# 1  Python  6  4
# 2  Python  7  5

# %%
df.insert(2,'Numbers',[100,200,300],allow_duplicates=True)  # Column will be added at 1st index
df
# Out:
#     a                 R  Numbers             E       D    R    R  \
# 0  10  Machine Learning      100  data Science  Python  100  100
# 1  20  Machine Learning      200  data Science  Python  200  100
# 2  30  Machine Learning      300  data Science  Python  300  100
#
#                   R       D       D  b  c
# 0  Machine Learning  Python  Python  5  3
# 1  Machine Learning  Python  Python  6  4
# 2  Machine Learning  Python  Python  7  5

# %%
df.insert(2,'Test',[100,200,np.nan],allow_duplicates=True)  # Column will be added at 1st index
df
# Out:
#     a                 R   Test  Numbers             E       D    R    R  \
# 0  10  Machine Learning  100.0      100  data Science  Python  100  100
# 1  20  Machine Learning  200.0      200  data Science  Python  200  100
# 2  30  Machine Learning    NaN      300  data Science  Python  300  100
#
#                   R       D       D  b  c
# 0  Machine Learning  Python  Python  5  3
# 1  Machine Learning  Python  Python  6  4
# 2  Machine Learning  Python  Python  7  5

# %% [markdown]
# # Merge DataFrames

# %% [markdown]
# # 1. append()

# %%
df1.append(df_list)
df1.append([df2,df3,df4])
df_new = df1.append(df2)

# %%
df1 = pd.DataFrame({'ASCII Value':[i for i in range(65,70)],
                   'Char' : [chr(i) for i in range(65,70)]})
df1
# Out:
#    ASCII Value Char
# 0           65    A
# 1           66    B
# 2           67    C
# 3           68    D
# 4           69    E

# %%
df2 = pd.DataFrame({'ASCII Value':[i for i in range(70,75)],
                   'Char' : [chr(i) for i in range(70,75)]})
df2
# Out:
#    ASCII Value Char
# 0           70    F
# 1           71    G
# 2           72    H
# 3           73    I
# 4           74    J

# %%
df3 = pd.DataFrame({'ASCII Value':[i for i in range(75,80)],
                   'Char' : [chr(i) for i in range(75,80)]})
df3
# Out:
#    ASCII Value Char
# 0           75    K
# 1           76    L
# 2           77    M
# 3           78    N
# 4           79    O

# %%
df1.append(df2)
# Out:
#    ASCII Value Char
# 0           65    A
# 1           66    B
# 2           67    C
# 3           68    D
# 4           69    E
# 0           70    F
# 1           71    G
# 2           72    H
# 3           73    I
# 4           74    J

# %%
df4 = df1.append(df3)
df4
# Out:
#    ASCII Value Char
# 0           65    A
# 1           66    B
# 2           67    C
# 3           68    D
# 4           69    E
# 0           75    K
# 1           76    L
# 2           77    M
# 3           78    N
# 4           79    O

# %%
df1.append([df2,df3])
# Out:
#    ASCII Value Char
# 0           65    A
# 1           66    B
# 2           67    C
# 3           68    D
# 4           69    E
# 0           70    F
# 1           71    G
# 2           72    H
# 3           73    I
# 4           74    J
# 0           75    K
# 1           76    L
# 2           77    M
# 3           78    N
# 4           79    O

# %%
df1.append([df2,df3],ignore_index=True)
# Out:
#     ASCII Value Char
# 0            65    A
# 1            66    B
# 2            67    C
# 3            68    D
# 4            69    E
# 5            70    F
# 6            71    G
# 7            72    H
# 8            73    I
# 9            74    J
# 10           75    K
# 11           76    L
# 12           77    M
# 13           78    N
# 14           79    O

# %%
df2.append([df1,df3],ignore_index=True)
# Out:
#     ASCII Value Char
# 0            70    F
# 1            71    G
# 2            72    H
# 3            73    I
# 4            74    J
# 5            65    A
# 6            66    B
# 7            67    C
# 8            68    D
# 9            69    E
# 10           75    K
# 11           76    L
# 12           77    M
# 13           78    N
# 14           79    O

# %% [markdown]
# # 2. concat()

# %%
df3
# Out:
#    ASCII Value Char
# 0           75    K
# 1           76    L
# 2           77    M
# 3           78    N
# 4           79    O

# %%
df_new = pd.concat([df1,df2])
df_new
# Out:
#    ASCII Value Char
# 0           65    A
# 1           66    B
# 2           67    C
# 3           68    D
# 4           69    E
# 0           70    F
# 1           71    G
# 2           72    H
# 3           73    I
# 4           74    J

# %%
df_new = pd.concat([df2,df3],ignore_index=True)
df_new
# Out:
#    ASCII Value Char
# 0           70    F
# 1           71    G
# 2           72    H
# 3           73    I
# 4           74    J
# 5           75    K
# 6           76    L
# 7           77    M
# 8           78    N
# 9           79    O

# %%
df_new = pd.concat([df2,df3],ignore_index=True,axis = 0)
df_new
# Out:
#    ASCII Value Char
# 0           70    F
# 1           71    G
# 2           72    H
# 3           73    I
# 4           74    J
# 5           75    K
# 6           76    L
# 7           77    M
# 8           78    N
# 9           79    O

# %%
df_new = pd.concat([df1,df2,df3],ignore_index=True,axis = 0)
df_new
# Out:
#     ASCII Value Char
# 0            65    A
# 1            66    B
# 2            67    C
# 3            68    D
# 4            69    E
# 5            70    F
# 6            71    G
# 7            72    H
# 8            73    I
# 9            74    J
# 10           75    K
# 11           76    L
# 12           77    M
# 13           78    N
# 14           79    O

# %%
df_new = pd.concat([df3,df2,df1],ignore_index=True,axis = 0)
df_new
# Out:
#     ASCII Value Char
# 0            75    K
# 1            76    L
# 2            77    M
# 3            78    N
# 4            79    O
# 5            70    F
# 6            71    G
# 7            72    H
# 8            73    I
# 9            74    J
# 10           65    A
# 11           66    B
# 12           67    C
# 13           68    D
# 14           69    E

# %%
df_new = pd.concat([df2,df3],ignore_index=True,axis = 1)
df_new
# Out:
#     0  1   2  3
# 0  70  F  75  K
# 1  71  G  76  L
# 2  72  H  77  M
# 3  73  I  78  N
# 4  74  J  79  O

# %%
df_new = pd.concat([df2,df3],ignore_index=False,axis = 1)
df_new
# Out:
#    ASCII Value Char  ASCII Value Char
# 0           70    F           75    K
# 1           71    G           76    L
# 2           72    H           77    M
# 3           73    I           78    N
# 4           74    J           79    O

# %%
df_new = pd.concat([df1,df2,df3],ignore_index=False,axis = 1)
df_new
# Out:
#    ASCII Value Char  ASCII Value Char  ASCII Value Char
# 0           65    A           70    F           75    K
# 1           66    B           71    G           76    L
# 2           67    C           72    H           77    M
# 3           68    D           73    I           78    N
# 4           69    E           74    J           79    O

# %%
df1 = pd.DataFrame({'ASCII Value':[i for i in range(65,68)],
                   'Char' : [chr(i) for i in range(65,68)]})
df1
# Out:
#    ASCII Value Char
# 0           65    A
# 1           66    B
# 2           67    C

# %%
df2 = pd.DataFrame({'ASCII Value':[i for i in range(70,75)],
                   'Char' : [chr(i) for i in range(70,75)]})
df2
# Out:
#    ASCII Value Char
# 0           70    F
# 1           71    G
# 2           72    H
# 3           73    I
# 4           74    J

# %%
df3 = pd.DataFrame({'ASCII Value':[i for i in range(75,78)],
                   'Char' : [chr(i) for i in range(75,78)]})
df3
# Out:
#    ASCII Value Char
# 0           75    K
# 1           76    L
# 2           77    M

# %%
df_new = pd.concat([df1,df2,df3],ignore_index=False,axis = 0)
df_new
# Out:
#    ASCII Value Char
# 0           65    A
# 1           66    B
# 2           67    C
# 0           70    F
# 1           71    G
# 2           72    H
# 3           73    I
# 4           74    J
# 0           75    K
# 1           76    L
# 2           77    M

# %%
df_new = pd.concat([df1,df2,df3],ignore_index=True,axis = 0)
df_new
# Out:
#     ASCII Value Char
# 0            65    A
# 1            66    B
# 2            67    C
# 3            70    F
# 4            71    G
# 5            72    H
# 6            73    I
# 7            74    J
# 8            75    K
# 9            76    L
# 10           77    M

# %%
df_new = pd.concat([df1,df2,df3],ignore_index=True,axis = 1)
df_new
# Out:
#       0    1   2  3     4    5
# 0  65.0    A  70  F  75.0    K
# 1  66.0    B  71  G  76.0    L
# 2  67.0    C  72  H  77.0    M
# 3   NaN  NaN  73  I   NaN  NaN
# 4   NaN  NaN  74  J   NaN  NaN

# %%
df_new = pd.concat([df1,df2],ignore_index=True,axis = 1)
df_new
# Out:
#       0    1   2  3
# 0  65.0    A  70  F
# 1  66.0    B  71  G
# 2  67.0    C  72  H
# 3   NaN  NaN  73  I
# 4   NaN  NaN  74  J

# %%
df_new = pd.concat([df1,df2],ignore_index=False,axis = 1)
df_new
# Out:
#    ASCII Value Char  ASCII Value Char
# 0         65.0    A           70    F
# 1         66.0    B           71    G
# 2         67.0    C           72    H
# 3          NaN  NaN           73    I
# 4          NaN  NaN           74    J

# %%
df_new = pd.concat([df1,df3],ignore_index=False,axis = 1)
df_new
# Out:
#    ASCII Value Char  ASCII Value Char
# 0           65    A           75    K
# 1           66    B           76    L
# 2           67    C           77    M

# %%
df_new = pd.concat([df1,df3],ignore_index=False,axis = 1,join = 'outer')
df_new
# Out:
#    ASCII Value Char  ASCII Value Char
# 0           65    A           75    K
# 1           66    B           76    L
# 2           67    C           77    M

# %%
# join = 'inner' >> Common index values

# %%
df_new = pd.concat([df1,df3],ignore_index=False,axis = 1,join = 'inner')
df_new
# Out:
#    ASCII Value Char  ASCII Value Char
# 0           65    A           75    K
# 1           66    B           76    L
# 2           67    C           77    M

# %%
df_new = pd.concat([df1,df2],ignore_index=False,axis = 1,join = 'outer')
df_new
# Out:
#    ASCII Value Char  ASCII Value Char
# 0         65.0    A           70    F
# 1         66.0    B           71    G
# 2         67.0    C           72    H
# 3          NaN  NaN           73    I
# 4          NaN  NaN           74    J

# %%
df_new = pd.concat([df1,df2],ignore_index=False,axis = 1,join = 'inner')
df_new
# Out:
#    ASCII Value Char  ASCII Value Char
# 0           65    A           70    F
# 1           66    B           71    G
# 2           67    C           72    H

# %%
df2
# Out:
#    ASCII Value Char
# 0           70    F
# 1           71    G
# 2           72    H
# 3           73    I
# 4           74    J

# %%
import pandas as pd
df1=pd.DataFrame({"Roll no":[1,2,3,4],
                 "Name":["A","B","C","D"]})
df1
# Out:
#    Roll no Name
# 0        1    A
# 1        2    B
# 2        3    C
# 3        4    D

# %%
df2=pd.DataFrame({"Adress":["ADF","fgh"],
                 "Name":["A","B"]})
df2
# Out:
#   Adress Name
# 0    ADF    A
# 1    fgh    B

# %%
df3=pd.DataFrame({"Roll no":[5,6,7,8],
                 "Name":["Aa","Bb","Cc","Dd"]})
df3
# Out:
#    Roll no Name
# 0        5   Aa
# 1        6   Bb
# 2        7   Cc
# 3        8   Dd

# %%
df_new=pd.concat([df1,df3])
df_new
# Out:
#    Roll no Name
# 0        1    A
# 1        2    B
# 2        3    C
# 3        4    D
# 0        5   Aa
# 1        6   Bb
# 2        7   Cc
# 3        8   Dd

# %%
df_new=pd.concat([df1,df2])
df_new
# Out:
#    Roll no Name Adress
# 0      1.0    A    NaN
# 1      2.0    B    NaN
# 2      3.0    C    NaN
# 3      4.0    D    NaN
# 0      NaN    A    ADF
# 1      NaN    B    fgh

# %%
df_new=pd.concat([df1,df2],join="inner")
df_new
# Out:
#   Name
# 0    A
# 1    B
# 2    C
# 3    D
# 0    A
# 1    B

# %%
df_new=pd.concat([df1,df2],axis=1)
df_new
# Out:
#    Roll no Name Adress Name
# 0        1    A    ADF    A
# 1        2    B    fgh    B
# 2        3    C    NaN  NaN
# 3        4    D    NaN  NaN

# %%
df_new=pd.concat([df1,df3],axis=0)
df_new
# Out:
#    Roll no Name
# 0        1    A
# 1        2    B
# 2        3    C
# 3        4    D
# 0        5   Aa
# 1        6   Bb
# 2        7   Cc
# 3        8   Dd

# %%
df_new=pd.concat([df1,df3],axis=0,join="inner")
df_new
# Out:
#    Roll no Name
# 0        1    A
# 1        2    B
# 2        3    C
# 3        4    D
# 0        5   Aa
# 1        6   Bb
# 2        7   Cc
# 3        8   Dd

# %%
df_new=pd.concat([df_new,df2],join="inner")
df_new
# Out:
#   Name
# 0    A
# 1    B
# 2    C
# 3    D
# 0   Aa
# 1   Bb
# 2   Cc
# 3   Dd
# 0    A
# 1    B

# %%
df_new=pd.concat([df_new,df2],join="outer")
df_new
# Out:
#   Name Adress
# 0    A    NaN
# 1    B    NaN
# 2    C    NaN
# 3    D    NaN
# 0   Aa    NaN
# 1   Bb    NaN
# 2   Cc    NaN
# 3   Dd    NaN
# 0    A    NaN
# 1    B    NaN
# 0    A    ADF
# 1    B    fgh
